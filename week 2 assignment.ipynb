# %% [markdown]
# # Analysis of Traffic Collisions in California

# %%
# !pip install pandas
import pandas as pd
import os
df = pd.read_csv('week 2/tableExport.csv')

# %% [markdown]
# ## Shape

# %%
df = pd.read_csv('week 2/tableExport.csv')
print(df.shape)
# Out:
# (486, 8)

# %% [markdown]
# ## Info

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   City     486 non-null    object
#  1   County   486 non-null    object
#  2   2018     486 non-null    object
#  3   2019     486 non-null    object
#  4   2020     486 non-null    object
#  5   2021     486 non-null    object
#  6   2022     486 non-null    object
#  7   Average  486 non-null    object
# dtypes: object(8)
# memory usage: 30.5+ KB
# None

# %% [markdown]
# ## Plot

# %%
print(df.dtypes)
columns_to_convert = ['2018', '2019', '2020', '2021', '2022']
for column in columns_to_convert:
    df[column] = pd.to_numeric(df[column], errors='coerce')
import matplotlib.pyplot as plt
df.plot(kind='bar', x='City', y='2021')
# Out:
# City       object
# County     object
# 2018       object
# 2019       object
# 2020       object
# 2021       object
# 2022       object
# Average    object
# dtype: object
# <Axes: xlabel='City'>

# %% [markdown]
# ## Value Counts

# %%
city_counts = df['City'].value_counts()
print(city_counts)
# Out:
# City
# Statewide       1
# SOLANA BEACH    1
# ANDERSON        1
# PATTERSON       1
# CALIMESA        1
#                ..
# PALM DESERT     1
# GILROY          1
# SAN JACINTO     1
# APPLE VALLEY    1
# TULELAKE        1
# Name: count, Length: 486, dtype: int64

# %% [markdown]
# ## Cities in California with the Highest Number of Collisions in 2021
# ### Data Filter

# %%
top_cities.plot(kind='bar', x='City', y='2021', figsize=(20, 10), rot=90)
plt.show()
